# %% [markdown]
# <a href="https://colab.research.google.com/github/YuanFan666/Project-for-ESE-5971/blob/main/VideoObjectDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Connect to local resources.

# %%
# !pip install jupyter_http_over_ws
# !jupyter-serverextension enable --py jupyter_http_over_ws
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 22.1 MB/s eta 0:00:00
# ...
# Enabling: jupyter_http_over_ws
# - Writing config: /root/.jupyter
#     - Validating...
#       jupyter_http_over_ws 0.0.7 OK

# %%
# %pip install ultralytics opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 7.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#    - -------------------------------------- 1.8/40.2 MB 8.9 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.2/40.2 MB 10.4 MB/s eta 0:00:04
#    ------ --------------------------------- 6.6/40.2 MB 10.3 MB/s eta 0:00:04
#    -------- ------------------------------- 8.9/40.2 MB 10.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 11.5/40.2 MB 10.8 MB/s eta 0:00:03
#    ------------- -------------------------- 13.9/40.2 MB 10.9 MB/s eta 0:00:03
#    ---------------- ----------------------- 16.3/40.2 MB 10.9 MB/s eta 0:00:03
#    ------------------ --------------------- 18.6/40.2 MB 10.9 MB/s eta 0:00:02
#    -------------------- ------------------- 21.0/40.2 MB 11.0 MB/s eta 0:00:02
# ...
